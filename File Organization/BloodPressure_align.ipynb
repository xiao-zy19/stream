# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/EICU/eicu-collaborative-research-database-2.0')

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import patient_id_age, blood_pressure, align_data

start_time_all = time.time()

_, _, patient_offset = patient_id_age()
print(f'Total number of patients: {len(patient_offset)}')
# print(f'Total number of patients: {len(patient_id)}')

# import Final_available_patients.csv
folder_path = '/content/drive/My Drive/Colab Notebooks'
file_name = 'Final_available_patients.csv'
# file_name = 'Final_available_patients_demo.csv'

df_final_available_patients = pd.read_csv(os.path.join(folder_path, file_name))
patient_id = df_final_available_patients['patientunitstayid'].unique()
patient_id = np.sort(patient_id)
print(f'Final available patients: {len(patient_id)}')
print(patient_id)

# %%
file_name = 'BloodPressure.csv'
_, _, _, _, _, _, _, _, BP, BP_index = blood_pressure(patient_id)
data_full, data_full_index = align_data(patient_id, patient_offset, BP, graph=False)

end_time_all = time.time()
print(f'Total time: {end_time_all - start_time_all} seconds')

# %%
folder_path = '/content/drive/My Drive/Colab Notebooks'
data_full.to_csv(os.path.join(folder_path, file_name), index=False)
print(f'Saved to {os.path.join(folder_path, file_name)}')
